# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("obese.csv")
if "Unnamed: 0" in df.columns:
    df = df.drop(columns="Unnamed: 0")
shape = df.shape
shape
# Out:
# (159, 1467)

# %%
print("Shape of the dataset:", df.shape)
print("columns: ", df.columns[:10])
print("\nData types: \n", df.dtypes.head())
# Out:
# Shape of the dataset: (159, 1467)
# columns:  Index(['Disease', 'Sex', 'Age', 'Race', 'AARSD1', 'ABHD14B', 'ABL1', 'ACAA1',
#        'ACAN', 'ACE2'],
#       dtype='object')
#
# Data types:
#  Disease     object
# Sex         object
# Age          int64
# Race        object
# AARSD1     float64
# dtype: object

# %%
categorical_cols = df.select_dtypes(include=['object']).columns
for col in categorical_cols:
    print(f"Unique values in {col}: ", df[col].unique())
# Out:
# Unique values in Disease:  ['RRMS' 'Healthy']
# Unique values in Sex:  ['Male' 'Female']
# Unique values in Race:  ['White' 'Unknown' 'Black' 'Asian' 'Native American']

# %%
missing = df.isnull().sum()
print("\nMissing values summary:\n", missing[missing > 0])
# Out:
# Missing values summary:
#  Series([], dtype: int64)
